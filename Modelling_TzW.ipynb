# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
dftrain = pd.read_csv('dftrain.csv',delimiter=',')

# %%
dftrain.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  69572                   1        2            0           11
# 1   8776                   0        2            0           20
# 2  34310                   1        1            0           21
# 3  67743                   0        0            0           90
# 4  19728                   0        0            0           18
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              5         109              1              1               1
# 1              2         280              1              1               2
# 2              4         250              1              1               1
# 3             63          58              1              1               3
# 4              1           0              1              1               4
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment  \
# 0            1             1                1      18    2225.0        1
# 1            2             2                1       7    1502.0        2
# 2            3             2                2       8    1511.0        3
# 3            4             1                2      31    1539.0        2
# 4            2             2                1    2017    2104.0        2
#
#    status_group
# 0             1
# 1             1
# 2             1
# 3             2
# 4             1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

# %%
features = list(dftrain.columns)
print features
# Out:
# ['id', 'water_availability', 'terrain', 'num_private', 'region_code', 'district_code', 'population', 'water_quality', 'quality_group', 'quantity_group', 'source_type', 'source_class', 'waterpoint_type', 'wp_age', 'daysdiff', 'payment', 'status_group']

# %%
selfeats = [features[1],features[2],features[3],features[4],features[5],features[6],features[7],features[8],features[9],features[10],features[11],features[12],features[13],features[14],features[15]]

# %%
trainfeats = dftrain[selfeats]
labels = dftrain['status_group']

# %%
clf = ExtraTreesClassifier()
clf = clf.fit(trainfeats,labels)

# %%
clf.feature_importances_
# Out:
# array([ 0.03329123,  0.01796841,  0.00338161,  0.06100113,  0.07694766,
#         0.12684107,  0.01593033,  0.0176505 ,  0.13753921,  0.04741611,
#         0.0115643 ,  0.09086236,  0.11472087,  0.20008682,  0.0447984 ])

# %%
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(trainfeats)
print(model.get_support())
X_new.shape
# Out:
# [False False False False  True  True False False  True False False  True
#   True  True False]
# (47520, 6)

# %%
clf2 = DecisionTreeClassifier()
clf2 = clf2.fit(X_new,labels)

# %%
dfvalidation = pd.read_csv('validation.csv',delimiter=',')

# %%
dfvalidation.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  45078                   0        2            0           19
# 1  31768                   1        2            0           80
# 2  36242                   0        2            0            3
# 3  18510                   1        0            0            4
# 4  45518                   0        0            0           12
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              4           0              1              1               1
# 1             13         860              1              1               1
# 2              4          30              1              1               1
# 3              8          40              1              1               2
# 4              6           0              1              1               1
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment  \
# 0            5             1                3    2017    2080.0        2
# 1            5             1                3      32    1546.0        3
# 2            1             1                0      41    1504.0        2
# 3            1             1                1      27    2223.0        6
# 4            6             2                1    2017    2108.0        2
#
#    status_group
# 0             1
# 1             1
# 2             3
# 3             1
# 4             1

# %%
dfvaltest = dfvalidation[['id', 'water_availability', 'terrain', 'num_private', 'region_code', 'district_code', 'population', 'water_quality', 'quality_group', 'quantity_group', 'source_type', 'source_class', 'waterpoint_type', 'wp_age', 'daysdiff','payment']].copy()

# %%
dfvaltest.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  45078                   0        2            0           19
# 1  31768                   1        2            0           80
# 2  36242                   0        2            0            3
# 3  18510                   1        0            0            4
# 4  45518                   0        0            0           12
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              4           0              1              1               1
# 1             13         860              1              1               1
# 2              4          30              1              1               1
# 3              8          40              1              1               2
# 4              6           0              1              1               1
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment
# 0            5             1                3    2017    2080.0        2
# 1            5             1                3      32    1546.0        3
# 2            1             1                0      41    1504.0        2
# 3            1             1                1      27    2223.0        6
# 4            6             2                1    2017    2108.0        2

# %%
feat2test = list(dfvaltest.columns)
selfeats = [feat2test[5],feat2test[6],feat2test[9],feat2test[12],feat2test[13],feat2test[14]]
valfeats = dfvaltest[selfeats]

# %%
dfvaltest['prediction'] = clf2.predict(valfeats)

# %%
dfvaltest.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  45078                   0        2            0           19
# 1  31768                   1        2            0           80
# 2  36242                   0        2            0            3
# 3  18510                   1        0            0            4
# 4  45518                   0        0            0           12
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              4           0              1              1               1
# 1             13         860              1              1               1
# 2              4          30              1              1               1
# 3              8          40              1              1               2
# 4              6           0              1              1               1
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment  \
# 0            5             1                3    2017    2080.0        2
# 1            5             1                3      32    1546.0        3
# 2            1             1                0      41    1504.0        2
# 3            1             1                1      27    2223.0        6
# 4            6             2                1    2017    2108.0        2
#
#    prediction
# 0           1
# 1           1
# 2           3
# 3           1
# 4           1

# %%
dfvaltest['status_group'] = dfvalidation['status_group']

# %% [markdown]
# <h3>#lets check the accuracy score....</h3>

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = dfvaltest['prediction']
y_true = dfvaltest['status_group']

# %%
accuracy_score(y_true,y_pred)
# Out:
# 0.74705387205387208

# %% [markdown]
# <h3>#open test dataframe</h3>

# %%
dftest = pd.read_csv('testsetfix.csv',delimiter=',')

# %%
dftest.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  50785                   0        2            0           21
# 1  51630                   0        2            0            2
# 2  17168                   0        2            0           13
# 3  45559                   0        0            0           80
# 4  49871                   1        2            0           10
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              3         321              1              1               4
# 1              2         300              1              1               2
# 2              2         500              1              1               2
# 3             43         250              1              1               3
# 4              3          60              1              1               1
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment
# 0            2             2                0       5    1532.0        2
# 1            1             1                1      17    1532.0        2
# 2            2             2                0       7    1535.0        2
# 3            5             1                0      30    1545.0        0
# 4            1             1                1      17    1481.0        6

# %%
feat2pred = list(dftest.columns)
selfeat_p = [feat2pred[5],feat2pred[6],feat2pred[9],feat2pred[12],feat2pred[13],feat2pred[14]]
predfeats = dftest[selfeat_p]

# %%
dftest['status_group'] = clf2.predict(predfeats)

# %%
dftest.head()
# Out:
#       id  water_availability  terrain  num_private  region_code  \
# 0  50785                   0        2            0           21
# 1  51630                   0        2            0            2
# 2  17168                   0        2            0           13
# 3  45559                   0        0            0           80
# 4  49871                   1        2            0           10
#
#    district_code  population  water_quality  quality_group  quantity_group  \
# 0              3         321              1              1               4
# 1              2         300              1              1               2
# 2              2         500              1              1               2
# 3             43         250              1              1               3
# 4              3          60              1              1               1
#
#    source_type  source_class  waterpoint_type  wp_age  daysdiff  payment  \
# 0            2             2                0       5    1532.0        2
# 1            1             1                1      17    1532.0        2
# 2            2             2                0       7    1535.0        2
# 3            5             1                0      30    1545.0        0
# 4            1             1                1      17    1481.0        6
#
#    status_group
# 0             2
# 1             1
# 2             1
# 3             2
# 4             1

# %%
dftest.loc[dftest['status_group']==3]
# Out:
#           id  water_availability  terrain  num_private  region_code  \
# 8      36301                   1        1            0           90
# 18     28330                   0        0            0           17
# 34     37034                   1        2            0           11
# 37       707                   1        2            3            3
# 38     48489                   0        0            0            5
# 56     17853                   0        2            0           19
# 71      8869                   1        0            0           10
# 87     20773                   0        0            0            1
# 135    30309                   0        2            0           17
# 137     3496                   0        0            0            5
# 141    74104                   0        0            0            1
# 192    13323                   0        0            0           19
# 198    52145                   0        0            0           90
# 236    14853                   0        0            0           12
# 249    72139                   1        2            0           21
# 266    39300                   0        0            0            1
# 274    67682                   0        2            0            2
# 281    64903                   0        2            0            2
# 294    19450                   1        0            0            5
# 297    23254                   1        1            0           10
# 332    70288                   0        0            0            1
# 356    38301                   0        2            0           16
# 359    61415                   0        2            0           19
# 372    68162                   0        2            0           16
# 378    45590                   0        0            0           12
# 409    51000                   0        0            0           18
# 437    55279                   0        0            0           17
# 440     1998                   0        0            0           18
# 490    31787                   0        2            0           19
# 496     3138                   0        0            0           17
# ...      ...                 ...      ...          ...          ...
# 14370  47689                   1        2            0            2
# 14385  46851                   0        2            0            5
# 14400  17105                   0        0            0           12
# 14409  51525                   1        2            0           16
# 14418  50629                   0        2            0            5
# 14478  57348                   0        0            0            1
# 14486  55433                   0        0            0            5
# 14490   4371                   1        2            0           16
# 14531  14280                   0        2            0            3
# 14559  41653                   0        2            0           13
# 14563  63295                   0        2            0            3
# 14574  15834                   0        2            0           11
# 14608  28800                   0        0            0           17
# 14624  26244                   0        0            0           12
# 14636  31723                   1        1            0           16
# 14659  17950                   1        0            0            5
# 14710  56401                   0        0            0           12
# 14717  44895                   1        1            0           15
# 14729  12363                   0        1            0           10
# 14738  71022                   0        0            0           17
# 14741  51268                   0        0            0           18
# 14742  65296                   0        0            0            3
# 14743  49042                   0        0            0           12
# 14745  47336                   1        2            0            5
# 14746  47648                   0        0            0           12
# 14775  49339                   0        0            0           17
# 14783  36768                   0        2            0           15
# 14787  26494                   0        2            0           20
# 14834  12592                   0        0            0            1
# 14842  57731                   1        1            0           16
#
#        district_code  population  water_quality  quality_group  \
# 8                 33          40              1              1
# 18                 5           0              1              1
# 34                 4         360              1              1
# 37                 2          45              1              1
# 38                 6           1              1              1
# 56                 1        1200              1              1
# 71                 1           1              1              1
# 87                 1           0              1              1
# 135                1         250              1              1
# 137                1         189              2              2
# 141                4           0              1              1
# 192                2           0              2              2
# 198               33          40              1              1
# 236                1           0              1              1
# 249                5        1800              1              1
# 266                1           0              1              1
# 274                2         150              1              1
# 281                1           1              1              1
# 294                3         200              1              1
# 297                1           1              1              1
# 332                1           0              1              1
# 356                1         350              1              1
# 359                1         300              1              1
# 372                1         450              1              1
# 378                7           0              1              1
# 409               30           0              1              1
# 437                3           0              1              1
# 440                2           0              1              1
# 490                1         350              1              1
# 496                2           0              1              1
# ...              ...         ...            ...            ...
# 14370              7         180              1              1
# 14385              1         150              1              1
# 14400              4           0              1              1
# 14409              2         410              1              1
# 14418              1         150              1              1
# 14478              1           0              1              1
# 14486              6         200              1              1
# 14490              2         310              1              1
# 14531              1           1              1              1
# 14559              2           1              1              1
# 14563              4           1              1              1
# 14574              4          50              1              1
# 14608              1           0              1              1
# 14624              7           0              5              5
# 14636              3         172              1              1
# 14659              3         107              1              1
# 14710              7           0              5              5
# 14717              1         280              1              1
# 14729              5         500              1              1
# 14738              5           0              1              1
# 14741              1           0              1              1
# 14742              3         603              1              1
# 14743              1           0              1              1
# 14745              1         250              1              1
# 14746              6           0              1              1
# 14775              8           0              2              2
# 14783              2         100              1              1
# 14787              1        1200              2              2
# 14834              1           0              1              1
# 14842              3         230              1              1
#
#        quantity_group  source_type  source_class  waterpoint_type  wp_age  \
# 8                   2            1             1                1      20
# 18                  4            2             2                1    2017
# 34                  1            6             2                1      39
# 37                  1            1             1                1      45
# 38                  2            6             2                1      33
# 56                  2            1             1                4      18
# 71                  1            6             2                1      31
# 87                  1            4             1                1    2017
# 135                 1            5             1                3      19
# 137                 1            4             1                1      12
# 141                 2            4             1                2    2017
# 192                 2            5             1                3    2017
# 198                 1            1             1                1      22
# 236                 1            4             1                1    2017
# 249                 1            4             1                2      12
# 266                 1            1             1                1    2017
# 274                 1            1             1                1      12
# 281                 4            2             2                1      17
# 294                 2            6             2                1      14
# 297                 1            4             1                2       6
# 332                 1            4             1                1    2017
# 356                 1            1             1                1       5
# 359                 2            5             1                3      23
# 372                 4            2             2                1      12
# 378                 1            6             2                1    2017
# 409                 2            1             1                1    2017
# 437                 4            2             2                0    2017
# 440                 1            1             1                1    2017
# 490                 2            5             1                0      13
# 496                 4            2             2                1    2017
# ...               ...          ...           ...              ...     ...
# 14370               2            6             2                1      53
# 14385               1            4             1                1      45
# 14400               2            6             2                1    2017
# 14409               1            6             2                2      16
# 14418               1            1             1                1       7
# 14478               2            1             1                1    2017
# 14486               1            6             2                1      50
# 14490               1            6             2                1      17
# 14531               2            1             1                1      10
# 14559               2            4             1                1      57
# 14563               1            1             1                0      47
# 14574               1            5             1                3      14
# 14608               2            5             1                3    2017
# 14624               4            6             2                1    2017
# 14636               1            6             2                2       8
# 14659               1            6             2                1      22
# 14710               4            6             2                1    2017
# 14717               1            1             1                1      30
# 14729               0            4             1                0       6
# 14738               1            5             1                0    2017
# 14741               1            1             1                1    2017
# 14742               1            6             2                1       8
# 14743               1            4             1                1    2017
# 14745               1            1             1                1      11
# 14746               1            5             1                3    2017
# 14775               1            5             1                0    2017
# 14783               2            4             1                3      32
# 14787               1            5             1                0      23
# 14834               2            1             1                1    2017
# 14842               1            6             2                2       8
#
#        daysdiff  payment  status_group
# 8        1544.0        3             3
# 18       1653.0        0             3
# 34       2212.0        6             3
# 37       1514.0        6             3
# 38       2240.0        2             3
# 56       2079.0        2             3
# 71       1533.0        6             3
# 87       2209.0        2             3
# 135      1537.0        2             3
# 137      2190.0        2             3
# 141      2225.0        0             3
# 192      2062.0        2             3
# 198      1524.0        2             3
# 236      2207.0        3             3
# 249      1519.0        3             3
# 266      2191.0        2             3
# 274      1483.0        0             3
# 281      1487.0        2             3
# 294      2210.0        6             3
# 297      1523.0        3             3
# 332      2191.0        2             3
# 356      1528.0        0             3
# 359      2091.0        2             3
# 372      1529.0        0             3
# 378      2208.0        1             3
# 409      2090.0        2             3
# 437      1651.0        2             3
# 440      2097.0        2             3
# 490      2086.0        2             3
# 496      1624.0        5             3
# ...         ...      ...           ...
# 14370    1505.0        3             3
# 14385    2209.0        2             3
# 14400    2082.0        2             3
# 14409    1533.0        6             3
# 14418    2211.0        2             3
# 14478    2191.0        2             3
# 14486    2237.0        2             3
# 14490    1528.0        6             3
# 14531    1503.0        6             3
# 14559    1550.0        0             3
# 14563    1486.0        6             3
# 14574    2239.0        2             3
# 14608    1548.0        2             3
# 14624    2192.0        2             3
# 14636    1540.0        6             3
# 14659    2229.0        6             3
# 14710    2192.0        2             3
# 14717    2087.0        1             3
# 14729    1510.0        0             3
# 14738    1640.0        0             3
# 14741    2090.0        2             3
# 14742    1413.0        2             3
# 14743    2210.0        2             3
# 14745    2186.0        3             3
# 14746    2197.0        4             3
# 14775    1640.0        3             3
# 14783    2068.0        2             3
# 14787    1598.0        0             3
# 14834    2212.0        6             3
# 14842    1540.0        6             3
#
# [860 rows x 17 columns]

# %%
submission = dftest[['id','status_group']].copy()

# %%
submission['status_group'].replace(1,'functional',inplace=True)
submission['status_group'].replace(2,'non functional',inplace=True)
submission['status_group'].replace(3,'functional needs repair',inplace=True)

# %%
submission.to_csv('submission6baggedDT_77.csv',sep=',',header=True,index=False)

# %%
print "done!"
# Out:
# done!

# %%
from sklearn.ensemble import BaggingClassifier

# %%
clf3 = BaggingClassifier(n_estimators=50)
clf3 = clf3.fit(X_new,labels)

# %%
dftest['status_group'] = clf3.predict(predfeats)

# %%
dfvaltest['prediction'] = clf3.predict(valfeats)

# %%
accuracy_score(y_true,y_pred)
# Out:
# 0.76986531986531992

# %% [markdown]
# Done! Kesimpulan: DT sebagai unstable ML algorithm (akurasi prediksi bisa berubah banyak jika jumlah data berubah) dapat dibantu akurasinya dengan teknik Bagging (Bootstrap Aggregating), yakni bagging ("mewadahi dalam tas") sample subset ke dalam banyak "bag" dan melakukan klasifikasi pada masing-masing wadah, lalu nilai agregat nya yang dipakai. Hal ini bertujuan mengurangi variansi. Untuk n_estimators (banyaknya "bag"/"tas"), perlu dicari nilai optimalnya, dalam kasus ini 50 paling optimal dengan hasil akurasi 0.77, naik dari semula (DT tanpa bagging) sebesar 0.74. Sehingga perlu dicari cara lain lagi untuk bisa lebih meningkatkan akurasi.

# %% [markdown]
# cara berikutnya mungkin kembali ke features engineering: membuat feature (kolom) baru yang bisa menggambarkan ciri khas/pattern dalam data. (pengibaratan: feature disini adalah seperti kumis pada wajah, atau bentuk bibir, saat harus mengklasifikasi wajah menjadi male/female)
